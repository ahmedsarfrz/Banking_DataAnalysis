# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/Edulyt India - Data for Project - 3 (2).xlsx",sheet_name=None)

# %%
type(df)
# Out:
# dict

# %% [markdown]
# ##Problem statement : 1

# %%
merge_1=pd.merge(df['New_Account'],df['New_Transaction'],on='account_id')

# %%
merge_1.drop(columns=['Unnamed: 0', 'frequency','k_symbol'], inplace=True)

# Display the resulting DataFrame
print(merge_1)
# Out:
#          account_id  district_id    date    type  \
# 0               576           55  930101  CREDIT
# 1               576           55  930111  CREDIT
# 2               576           55  930131  CREDIT
# 3               576           55  930211  CREDIT
# 4               576           55  930228  CREDIT
# ...             ...          ...     ...     ...
# 1048570        3276            1  981206   DEBIT
# 1048571        3276            1  981206  CREDIT
# 1048572        3276            1  981208   DEBIT
# 1048573        3276            1  981208   DEBIT
# 1048574        3276            1  981213   DEBIT
#
#                             operation  amount  balance
# 0                      CREDIT IN CASH   900.0    900.0
# 1        COLLECTION FROM ANOTHER BANK  6207.0   7107.0
# 2                                 NaN    20.1   7127.1
# 3        COLLECTION FROM ANOTHER BANK  6207.0  13334.1
# 4                                 NaN    29.6  13363.7
# ...

# %%
credit_transactions = merge_1[merge_1['type'] == 'CREDIT']

# %%
credit_transactions
# Out:
#          account_id  district_id    date    type  \
# 0               576           55  930101  CREDIT
# 1               576           55  930111  CREDIT
# 2               576           55  930131  CREDIT
# 3               576           55  930211  CREDIT
# 4               576           55  930228  CREDIT
# ...             ...          ...     ...     ...
# 1048560        3276            1  981025  CREDIT
# 1048562        3276            1  981031  CREDIT
# 1048564        3276            1  981106  CREDIT
# 1048569        3276            1  981130  CREDIT
# 1048571        3276            1  981206  CREDIT
#
#                             operation  amount  balance
# 0                      CREDIT IN CASH   900.0    900.0
# 1        COLLECTION FROM ANOTHER BANK  6207.0   7107.0
# 2                                 NaN    20.1   7127.1
# 3        COLLECTION FROM ANOTHER BANK  6207.0  13334.1
# 4                                 NaN    29.6  13363.7
# ...

# %%
district_data = df['District'][['A1', 'A2', 'A3']]

# %%
district_data
# Out:
#     A1               A2               A3
# 0    1      Hl.m. Praha           Prague
# 1    2          Benesov  central Bohemia
# 2    3           Beroun  central Bohemia
# 3    4           Kladno  central Bohemia
# 4    5            Kolin  central Bohemia
# ..  ..              ...              ...
# 72  73            Opava    north Moravia
# 73  74  Ostrava - mesto    north Moravia
# 74  75           Prerov    north Moravia
# 75  76          Sumperk    north Moravia
# 76  77           Vsetin    north Moravia
#
# [77 rows x 3 columns]

# %%
credit_transactions_with_district = pd.merge(credit_transactions, district_data, left_on='district_id', right_on='A1')

# %%
credit_transactions_with_district
# Out:
#         account_id  district_id    date    type                     operation  \
# 0              576           55  930101  CREDIT                CREDIT IN CASH
# 1              576           55  930111  CREDIT  COLLECTION FROM ANOTHER BANK
# 2              576           55  930131  CREDIT                           NaN
# 3              576           55  930211  CREDIT  COLLECTION FROM ANOTHER BANK
# 4              576           55  930228  CREDIT                           NaN
# ...            ...          ...     ...     ...                           ...
# 400204        2152           22  981006  CREDIT  COLLECTION FROM ANOTHER BANK
# 400205        2152           22  981031  CREDIT                           NaN
# 400206        2152           22  981106  CREDIT  COLLECTION FROM ANOTHER BANK
# 400207        2152           22  981130  CREDIT                           NaN
# 400208        2152           22  981206  CREDIT  COLLECTION FROM ANOTHER BANK
#
# ...

# %%
moravia_and_prague_accounts = credit_transactions_with_district[
    (credit_transactions_with_district['A3'] == 'north Moravia') |
    (credit_transactions_with_district['A2'] == 'Hl.m. Praha') |
    (credit_transactions_with_district['A3'] == 'south Moravia')
]

# %%
moravia_and_prague_accounts['date']=pd.to_datetime(moravia_and_prague_accounts['date'], format='%y%m%d')
moravia_and_prague_accounts['date']=moravia_and_prague_accounts['date'].dt.strftime('%Y-%m-%d')
moravia_and_prague_accounts
# Out:
# <ipython-input-13-0e3e347105c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   moravia_and_prague_accounts['date']=pd.to_datetime(moravia_and_prague_accounts['date'], format='%y%m%d')
# <ipython-input-13-0e3e347105c0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   moravia_and_prague_accounts['date']=moravia_and_prague_accounts['date'].dt.strftime('%Y-%m-%d')
#         account_id  district_id        date    type  \
# 0              576           55  1993-01-01  CREDIT
# ...

# %%
account_wise_aggregated = moravia_and_prague_accounts.groupby('account_id').agg({
    'amount': 'sum',}).reset_index()

# %%
account_wise_aggregated
# Out:
#       account_id     amount
# 0              2  1596896.8
# 1              7   629947.7
# 2              8   892467.3
# 3              9   360060.5
# 4             10   549685.2
# ...          ...        ...
# 2120       11328   694902.5
# 2121       11349  1995489.2
# 2122       11359  1511358.6
# 2123       11362   684107.9
# 2124       11382  1351806.1
#
# [2125 rows x 2 columns]

# %%
moravia_and_prague_accounts['date'] = pd.to_datetime(moravia_and_prague_accounts['date'], format='%Y-%m-%d')

moravia_and_prague_accounts['month'] = moravia_and_prague_accounts['date'].dt.to_period('M')

month_wise_aggregated = moravia_and_prague_accounts.groupby('month').agg({
    'amount': 'sum'  # Get the last (most recent) value of 'balance' for each month
}).reset_index()

print(month_wise_aggregated)
# Out:
#       month      amount
# 0   1993-01    234974.8
# 1   1993-02   1234416.7
# 2   1993-03   1731283.8
# 3   1993-04   2674191.4
# 4   1993-05   3605568.2
# ..      ...         ...
# 67  1998-08  36451698.0
# 68  1998-09  35993341.2
# 69  1998-10  36294103.1
# 70  1998-11  36515600.8
# 71  1998-12  39385824.5
#
# [72 rows x 2 columns]
# <ipython-input-16-365c0fad8efa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   moravia_and_prague_accounts['date'] = pd.to_datetime(moravia_and_prague_accounts['date'], format='%Y-%m-%d')
# <ipython-input-16-365c0fad8efa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ##Problem statement - 2

# %%
table1=df['New_Transaction']
table1
# Out:
#          Unnamed: 0  account_id    date    type        operation   amount  \
# 0                 1        2378  930101  CREDIT   CREDIT IN CASH    700.0
# 1                 2         576  930101  CREDIT   CREDIT IN CASH    900.0
# 2                 3         704  930101  CREDIT   CREDIT IN CASH   1000.0
# 3                 4        3818  930101  CREDIT   CREDIT IN CASH    600.0
# 4                 5        1972  930102  CREDIT   CREDIT IN CASH    400.0
# ...             ...         ...     ...     ...              ...      ...
# 1048570     1048571        3779  981219   DEBIT  CASH WITHDRAWAL  12200.0
# 1048571     1048572        3787  981219   DEBIT  CASH WITHDRAWAL   2600.0
# 1048572     1048573        3789  981219   DEBIT  CASH WITHDRAWAL   4900.0
# 1048573     1048574        3791  981219   DEBIT  CASH WITHDRAWAL  23500.0
# 1048574     1048575        3789  981219   DEBIT  CASH WITHDRAWAL  11100.0
#
#          balance k_symbol
# 0          700.0      NaN
# ...

# %%
table1.drop(columns=['Unnamed: 0', 'balance','k_symbol','operation'], inplace=True)

# %%
table1
# Out:
#          account_id    date    type   amount
# 0              2378  930101  CREDIT    700.0
# 1               576  930101  CREDIT    900.0
# 2               704  930101  CREDIT   1000.0
# 3              3818  930101  CREDIT    600.0
# 4              1972  930102  CREDIT    400.0
# ...             ...     ...     ...      ...
# 1048570        3779  981219   DEBIT  12200.0
# 1048571        3787  981219   DEBIT   2600.0
# 1048572        3789  981219   DEBIT   4900.0
# 1048573        3791  981219   DEBIT  23500.0
# 1048574        3789  981219   DEBIT  11100.0
#
# [1048575 rows x 4 columns]

# %%
table1=pd.merge(table1,df['New_Account'],on="account_id")

# %%
table1
# Out:
#          account_id    date    type   amount  district_id         frequency
# 0              2378  930101  CREDIT    700.0           16  MONTHLY ISSUANCE
# 1              2378  930122  CREDIT   7268.0           16  MONTHLY ISSUANCE
# 2              2378  930123  CREDIT  14440.0           16  MONTHLY ISSUANCE
# 3              2378  930124  CREDIT  49752.0           16  MONTHLY ISSUANCE
# 4              2378  930126  CREDIT  21899.0           16  MONTHLY ISSUANCE
# ...             ...     ...     ...      ...          ...               ...
# 1048570        1573  981130  CREDIT     70.8           63  MONTHLY ISSUANCE
# 1048571        1573  981130   DEBIT   2560.0           63  MONTHLY ISSUANCE
# 1048572        1573  981130   DEBIT     14.6           63  MONTHLY ISSUANCE
# 1048573        1573  981209  CREDIT   5492.0           63  MONTHLY ISSUANCE
# 1048574        1573  981211   DEBIT   3638.0           63  MONTHLY ISSUANCE
#
# [1048575 rows x 6 columns]

# %%
del table1['frequency']
table1
# Out:
#          account_id    date    type   amount  district_id
# 0              2378  930101  CREDIT    700.0           16
# 1              2378  930122  CREDIT   7268.0           16
# 2              2378  930123  CREDIT  14440.0           16
# 3              2378  930124  CREDIT  49752.0           16
# 4              2378  930126  CREDIT  21899.0           16
# ...             ...     ...     ...      ...          ...
# 1048570        1573  981130  CREDIT     70.8           63
# 1048571        1573  981130   DEBIT   2560.0           63
# 1048572        1573  981130   DEBIT     14.6           63
# 1048573        1573  981209  CREDIT   5492.0           63
# 1048574        1573  981211   DEBIT   3638.0           63
#
# [1048575 rows x 5 columns]

# %%
table1=table1.merge(df['District'],left_on='district_id',right_on='A1')

# %%
table1
# Out:
#          account_id    date    type   amount  district_id  A1  \
# 0              2378  930101  CREDIT    700.0           16  16
# 1              2378  930122  CREDIT   7268.0           16  16
# 2              2378  930123  CREDIT  14440.0           16  16
# 3              2378  930124  CREDIT  49752.0           16  16
# 4              2378  930126  CREDIT  21899.0           16  16
# ...             ...     ...     ...      ...          ...  ..
# 1048570        2152  981130   DEBIT     14.6           22  22
# 1048571        2152  981130  CREDIT     95.8           22  22
# 1048572        2152  981205   DEBIT   3191.0           22  22
# 1048573        2152  981206  CREDIT   4880.0           22  22
# 1048574        2152  981206   DEBIT   1200.0           22  22
#
#                         A2             A3     A4  A5  ...  A7  A8  A9   A10  \
# 0        Jindrichuv Hradec  south Bohemia  93931  74  ...  10   1   8  56.9
# ...

# %%
del table1['A6']
del table1['A7']
del table1['A8']
del table1['A9']
del table1['A10']
del table1['A11']
del table1['A12']
del table1['A13']
del table1['A14']

# %%
table1
# Out:
#          account_id    date    type   amount  district_id  A1  \
# 0              2378  930101  CREDIT    700.0           16  16
# 1              2378  930122  CREDIT   7268.0           16  16
# 2              2378  930123  CREDIT  14440.0           16  16
# 3              2378  930124  CREDIT  49752.0           16  16
# 4              2378  930126  CREDIT  21899.0           16  16
# ...             ...     ...     ...      ...          ...  ..
# 1048570        2152  981130   DEBIT     14.6           22  22
# 1048571        2152  981130  CREDIT     95.8           22  22
# 1048572        2152  981205   DEBIT   3191.0           22  22
# 1048573        2152  981206  CREDIT   4880.0           22  22
# 1048574        2152  981206   DEBIT   1200.0           22  22
#
#                         A2             A3     A4  A5   A15   A16
# 0        Jindrichuv Hradec  south Bohemia  93931  74  1874  1913
# 1        Jindrichuv Hradec  south Bohemia  93931  74  1874  1913
# ...

# %%
table1.drop(columns=['A1','A5','A15','A16'],inplace=True)

# %%
table1
# Out:
#          account_id    date    type   amount  district_id                 A2  \
# 0              2378  930101  CREDIT    700.0           16  Jindrichuv Hradec
# 1              2378  930122  CREDIT   7268.0           16  Jindrichuv Hradec
# 2              2378  930123  CREDIT  14440.0           16  Jindrichuv Hradec
# 3              2378  930124  CREDIT  49752.0           16  Jindrichuv Hradec
# 4              2378  930126  CREDIT  21899.0           16  Jindrichuv Hradec
# ...             ...     ...     ...      ...          ...                ...
# 1048570        2152  981130   DEBIT     14.6           22          Domazlice
# 1048571        2152  981130  CREDIT     95.8           22          Domazlice
# 1048572        2152  981205   DEBIT   3191.0           22          Domazlice
# 1048573        2152  981206  CREDIT   4880.0           22          Domazlice
# 1048574        2152  981206   DEBIT   1200.0           22          Domazlice
#
#                     A3     A4
# ...

# %%
table1=table1.sort_values(by=['A4'],ascending=False)

# %%
table1
# Out:
#         account_id    date    type   amount  district_id           A2  \
# 162942        3449  970120   DEBIT    500.0            1  Hl.m. Praha
# 140901        6118  970930   DEBIT     30.0            1  Hl.m. Praha
# 140891        6118  970818   DEBIT   3600.0            1  Hl.m. Praha
# 140892        6118  970819  CREDIT  20645.0            1  Hl.m. Praha
# 140893        6118  970830   DEBIT   7200.0            1  Hl.m. Praha
# ...            ...     ...     ...      ...          ...          ...
# 881818        3136  960409   DEBIT   3489.0           69      Jesenik
# 881819        3136  960414   DEBIT   2655.0           69      Jesenik
# 881820        3136  960423   DEBIT   2100.0           69      Jesenik
# 881821        3136  960430   DEBIT     14.6           69      Jesenik
# 883172        4514  980531  CREDIT    218.0           69      Jesenik
#
#                    A3       A4
# 162942         Prague  1204953
# 140901         Prague  1204953
# ...

# %%
val=table1.iloc[:,7]
dat=set(i for i in val) #for taking top 5 districts of High populated and low populated here used set because set is ordered and avoid duplicates
dat
# Out:
# {42821,
#  45714,
#  51313,
#  51428,
#  53921,
#  58400,
#  58796,
#  67298,
#  70646,
#  70699,
#  72541,
#  74062,
#  75232,
#  75637,
#  75685,
#  77917,
#  77963,
#  78955,
#  81344,
#  85852,
#  86513,
#  87419,
#  88757,
#  88768,
#  88884,
#  92084,
#  93931,
#  94725,
#  94812,
#  95616,
#  95907,
#  102609,
#  103347,
#  105058,
#  105606,
#  106054,
#  107870,
#  107911,
#  108871,
#  109164,
#  110643,
#  112065,
#  112709,
#  114006,
#  114200,
#  117897,
#  118650,
#  119895,
#  121947,
#  122603,
#  124605,
#  125236,
#  125832,
#  127369,
#  128118,
#  133777,
#  138032,
#  139012,
#  145688,
#  148545,
#  149893,
#  157042,
#  159617,
#  161227,
#  161854,
#  161954,
#  162580,
#  170449,
#  177686,
#  182027,
#  197099,
#  226122,
#  228848,
#  285387,
#  323870,
#  387570,
#  1204953}

# %%
table1=table1[(table1['A4']==42821)|(table1['A4']==45714)|
           (table1['A4']==51313)|
            (table1['A4']==53921)|
             (table1['A4']==51428)|
              (table1['A4']==228848)|
               (table1['A4']==285387)|
                (table1['A4']==323870)|
                 (table1['A4']==387570)|
                  (table1['A4']==1204953)]
table1
# Out:
#         account_id    date    type   amount  district_id           A2  \
# 162942        3449  970120   DEBIT    500.0            1  Hl.m. Praha
# 140901        6118  970930   DEBIT     30.0            1  Hl.m. Praha
# 140891        6118  970818   DEBIT   3600.0            1  Hl.m. Praha
# 140892        6118  970819  CREDIT  20645.0            1  Hl.m. Praha
# 140893        6118  970830   DEBIT   7200.0            1  Hl.m. Praha
# ...            ...     ...     ...      ...          ...          ...
# 881818        3136  960409   DEBIT   3489.0           69      Jesenik
# 881819        3136  960414   DEBIT   2655.0           69      Jesenik
# 881820        3136  960423   DEBIT   2100.0           69      Jesenik
# 881821        3136  960430   DEBIT     14.6           69      Jesenik
# 883172        4514  980531  CREDIT    218.0           69      Jesenik
#
#                    A3       A4
# 162942         Prague  1204953
# 140901         Prague  1204953
# ...

# %%
table1=table1.sort_values(by="date",ascending=False)
table1
# Out:
#         account_id    date    type   amount  district_id               A2  \
# 432923        5891  981219   DEBIT   4700.0           54     Brno - mesto
# 58158         3048  981219   DEBIT   3000.0           74  Ostrava - mesto
# 208092        1890  981219   DEBIT  14849.0            1      Hl.m. Praha
# 27364         7753  981219   DEBIT   2200.0           74  Ostrava - mesto
# 857728         122  981219   DEBIT  28500.0           31           Tachov
# ...            ...     ...     ...      ...          ...              ...
# 283268        2881  930104  CREDIT    700.0           70          Karvina
# 270472        2357  930104  CREDIT    800.0           19       Prachatice
# 79686         1539  930103  CREDIT    600.0            1      Hl.m. Praha
# 24781         2484  930103  CREDIT   1100.0           74  Ostrava - mesto
# 24222         3818  930101  CREDIT    600.0           74  Ostrava - mesto
#
#                    A3       A4
# 432923  south Moravia   387570
# ...

# %%
compute=table1[table1['date']>980931]
compute
# Out:
#         account_id    date   type   amount  district_id               A2  \
# 432923        5891  981219  DEBIT   4700.0           54     Brno - mesto
# 58158         3048  981219  DEBIT   3000.0           74  Ostrava - mesto
# 208092        1890  981219  DEBIT  14849.0            1      Hl.m. Praha
# 27364         7753  981219  DEBIT   2200.0           74  Ostrava - mesto
# 857728         122  981219  DEBIT  28500.0           31           Tachov
# ...            ...     ...    ...      ...          ...              ...
# 726887        2262  981001  DEBIT  46400.0           13         Rakovnik
# 455867        2610  981001  DEBIT    880.0           54     Brno - mesto
# 111841        3152  981001  DEBIT   4100.0            1      Hl.m. Praha
# 192785        2156  981001  DEBIT  16600.0            1      Hl.m. Praha
# 131627        6806  981001  DEBIT  13200.0            1      Hl.m. Praha
#
#                      A3       A4
# 432923    south Moravia   387570
# ...

# %%
compute=compute.sort_values('A4')
compute
# Out:
#         account_id    date    type   amount  district_id           A2  \
# 882030        3136  981031   DEBIT     14.6           69      Jesenik
# 886797         242  981103   DEBIT   3480.0           69      Jesenik
# 887847        1390  981206  CREDIT  16107.0           69      Jesenik
# 885697        2890  981119   DEBIT   2100.0           69      Jesenik
# 883201        4514  981130  CREDIT    201.8           69      Jesenik
# ...            ...     ...     ...      ...          ...          ...
# 174140        9024  981130  CREDIT    144.2            1  Hl.m. Praha
# 96284         4093  981031   DEBIT     14.6            1  Hl.m. Praha
# 174139        9024  981130   DEBIT     14.6            1  Hl.m. Praha
# 193051        3098  981130  CREDIT    170.9            1  Hl.m. Praha
# 131627        6806  981001   DEBIT  13200.0            1  Hl.m. Praha
#
#                    A3       A4
# 882030  north Moravia    42821
# 886797  north Moravia    42821
# ...

# %%
values=compute.iloc[:,7]
data=set(i for i in values)
data
# Out:
# {42821, 45714, 51313, 51428, 53921, 228848, 285387, 323870, 387570, 1204953}

# %%
compute.groupby('A2')['amount'].sum()
# Out:
# A2
# Brno - mesto       11083612.6
# Frydek - Mistek     9516532.6
# Hl.m. Praha        56937738.8
# Jesenik             5060647.5
# Karvina            14162105.1
# Ostrava - mesto    13694970.2
# Prachatice          6093109.1
# Rakovnik            4454667.4
# Rokycany            4492728.3
# Tachov              4576710.5
# Name: amount, dtype: float64

# %%
lp_dist_tab=compute[(compute['A4']==42821)|(compute['A4']==45714)|(compute['A4']==51313)|(compute['A4']==53921)|(compute['A4']==51428)]

lp_dist_tab
# Out:
#         account_id    date    type   amount  district_id        A2  \
# 882030        3136  981031   DEBIT     14.6           69   Jesenik
# 886797         242  981103   DEBIT   3480.0           69   Jesenik
# 887847        1390  981206  CREDIT  16107.0           69   Jesenik
# 885697        2890  981119   DEBIT   2100.0           69   Jesenik
# 883201        4514  981130  CREDIT    201.8           69   Jesenik
# ...            ...     ...     ...      ...          ...       ...
# 721574         419  981212  CREDIT   6900.0           13  Rakovnik
# 721266        3323  981211   DEBIT  14000.0           13  Rakovnik
# 719902        8261  981112   DEBIT  16700.0           13  Rakovnik
# 727348         859  981130  CREDIT    156.4           13  Rakovnik
# 724297        5066  981031  CREDIT     11.5           13  Rakovnik
#
#                      A3     A4
# 882030    north Moravia  42821
# 886797    north Moravia  42821
# 887847    north Moravia  42821
# 885697    north Moravia  42821
# ...

# %%
lp_dist_tab.groupby('A2')['amount'].sum()
# Out:
# A2
# Jesenik       5060647.5
# Prachatice    6093109.1
# Rakovnik      4454667.4
# Rokycany      4492728.3
# Tachov        4576710.5
# Name: amount, dtype: float64

# %%
hp_dist_tab=compute[(compute['A4']==228848)|(compute['A4']==323870)|(compute['A4']==387570)|(compute['A4']==1204953)|(compute['A4']==285387)]
hp_dist_tab
# Out:
#         account_id    date    type   amount  district_id               A2  \
# 414221         218  981130  CREDIT    231.3           68  Frydek - Mistek
# 415886        2604  981203   DEBIT   1200.0           68  Frydek - Mistek
# 413769        2015  981127   DEBIT   4680.0           68  Frydek - Mistek
# 403850         115  981204   DEBIT   4900.0           68  Frydek - Mistek
# 417317        2917  981130  CREDIT    144.0           68  Frydek - Mistek
# ...            ...     ...     ...      ...          ...              ...
# 174140        9024  981130  CREDIT    144.2            1      Hl.m. Praha
# 96284         4093  981031   DEBIT     14.6            1      Hl.m. Praha
# 174139        9024  981130   DEBIT     14.6            1      Hl.m. Praha
# 193051        3098  981130  CREDIT    170.9            1      Hl.m. Praha
# 131627        6806  981001   DEBIT  13200.0            1      Hl.m. Praha
#
#                    A3       A4
# 414221  north Moravia   228848
# ...

# %%
hp_dist_tab.groupby('A2')['amount'].sum()
# Out:
# A2
# Brno - mesto       11083612.6
# Frydek - Mistek     9516532.6
# Hl.m. Praha        56937738.8
# Karvina            14162105.1
# Ostrava - mesto    13694970.2
# Name: amount, dtype: float64

# %% [markdown]
# ##Problem statement : 3

# %%
CARD=df['New_Card']
CARD
# Out:
#      card_id  disp_id     type  issued
# 0       1005     9285  CLASSIC  931107
# 1        104      588  CLASSIC  940119
# 2        747     4915  CLASSIC  940205
# 3         70      439  CLASSIC  940208
# 4        577     3687  CLASSIC  940215
# ..       ...      ...      ...     ...
# 887      125      694     GOLD  981226
# 888      674     4360  CLASSIC  981228
# 889      322     2063  CLASSIC  981228
# 890      685     4467  CLASSIC  981229
# 891      635     4083  CLASSIC  981229
#
# [892 rows x 4 columns]

# %%
client = df['New_Client']  # Assuming you have already selected the 'New_Client' column.
# To drop the 'Unnamed: 0' column from the 'client' DataFrame:
client = client.drop('Unnamed: 0', axis=1)
client
# Out:
#       client_id  birth_number  district_id  gender  age   age_levels
# 0             1        701213           18  FEMALE   29        ADULT
# 1             2        450204            1    MALE   54  MIDDLE AGED
# 2             3        401009            1  FEMALE   59  MIDDLE AGED
# 3             4        561201            5    MALE   43  MIDDLE AGED
# 4             5        600703            5  FEMALE   39  MIDDLE AGED
# ...         ...           ...          ...     ...  ...          ...
# 5364      13955        451030            1  FEMALE   54  MIDDLE AGED
# 5365      13956        430406            1    MALE   56  MIDDLE AGED
# 5366      13968        680413           61    MALE   31        ADULT
# 5367      13971        621019           67  FEMALE   37  MIDDLE AGED
# 5368      13998        530812           74  FEMALE   46  MIDDLE AGED
#
# [5369 rows x 6 columns]

# %%
disp = df['New_Disposition']  # Assuming you have already selected the 'New_Disposition' column.
# To drop 'account_id' and 'type' columns from the 'disp' DataFrame:
disp = disp.drop(columns=['account_id', 'type'])
disp
# Out:
#       disp_id  client_id
# 0           1          1
# 1           2          2
# 2           3          3
# 3           4          4
# 4           5          5
# ...       ...        ...
# 5364    13647      13955
# 5365    13648      13956
# 5366    13660      13968
# 5367    13663      13971
# 5368    13690      13998
#
# [5369 rows x 2 columns]

# %%
merge=pd.merge(client,disp,on='client_id')
merge
# Out:
#       client_id  birth_number  district_id  gender  age   age_levels  disp_id
# 0             1        701213           18  FEMALE   29        ADULT        1
# 1             2        450204            1    MALE   54  MIDDLE AGED        2
# 2             3        401009            1  FEMALE   59  MIDDLE AGED        3
# 3             4        561201            5    MALE   43  MIDDLE AGED        4
# 4             5        600703            5  FEMALE   39  MIDDLE AGED        5
# ...         ...           ...          ...     ...  ...          ...      ...
# 5364      13955        451030            1  FEMALE   54  MIDDLE AGED    13647
# 5365      13956        430406            1    MALE   56  MIDDLE AGED    13648
# 5366      13968        680413           61    MALE   31        ADULT    13660
# 5367      13971        621019           67  FEMALE   37  MIDDLE AGED    13663
# 5368      13998        530812           74  FEMALE   46  MIDDLE AGED    13690
#
# [5369 rows x 7 columns]

# %%
merge_1=pd.merge(merge,CARD,on='disp_id')
merge_1=merge_1.drop(columns=['client_id','type'])
merge_1
# Out:
#      birth_number  district_id  gender  age   age_levels  disp_id  card_id  \
# 0          351016           60    MALE   64  MIDDLE AGED        9        1
# 1          421228           47    MALE   57  MIDDLE AGED       19        2
# 2          680827           22    MALE   31        ADULT       41        3
# 3          350817           68    MALE   64  MIDDLE AGED       42        4
# 4          791202           36  FEMALE   20        YOUTH       51        5
# ..            ...          ...     ...  ...          ...      ...      ...
# 887        700726           16    MALE   29        ADULT    13312     1230
# 888        630516           70    MALE   36  MIDDLE AGED    13382     1233
# 889        760120            1  FEMALE   23        YOUTH    13386     1234
# 890        801113           12  FEMALE   19        YOUTH    13442     1239
# 891        680413           61    MALE   31        ADULT    13660     1247
#
#      issued
# 0    981016
# 1    980313
# 2    950903
# 3    981126
# ...

# %%
# Filter the rows with 'MIDDLE AGED' females
mid_age_females = merge_1[(merge_1['age_levels'] == 'MIDDLE AGED') & (merge_1['gender'] == 'FEMALE')]
mid_age_females
# Out:
#      birth_number  district_id  gender  age   age_levels  disp_id  card_id  \
# 8          560218            1  FEMALE   43  MIDDLE AGED       77       10
# 11         461117           72  FEMALE   53  MIDDLE AGED       87       13
# 15         501227           21  FEMALE   49  MIDDLE AGED      127       17
# 21         611219           31  FEMALE   38  MIDDLE AGED      146       23
# 23         450703           40  FEMALE   54  MIDDLE AGED      158       25
# ..            ...          ...     ...  ...          ...      ...      ...
# 861        460827           76  FEMALE   53  MIDDLE AGED    12070     1154
# 863        500505           62  FEMALE   49  MIDDLE AGED    12269     1164
# 865        620720           69  FEMALE   37  MIDDLE AGED    12335     1167
# 867        400525           21  FEMALE   59  MIDDLE AGED    12442     1173
# 880        621103            1  FEMALE   37  MIDDLE AGED    12826     1199
#
#      issued
# 8    961207
# 11   940629
# 15   980607
# 21   981003
# ...

# %%
count=mid_age_females['age_levels'].value_counts()['MIDDLE AGED']
count
# Out:
# 227

# %% [markdown]
# ##PROBLEM STATEMENT : 4

# %%
d1=df['District']
d1=d1.drop(columns=['A4','A5','A6','A7','A8','A9','A10','A12','A13','A14','A15','A16'])
d1
# Out:
#     A1               A2               A3    A11
# 0    1      Hl.m. Praha           Prague  12541
# 1    2          Benesov  central Bohemia   8507
# 2    3           Beroun  central Bohemia   8980
# 3    4           Kladno  central Bohemia   9753
# 4    5            Kolin  central Bohemia   9307
# ..  ..              ...              ...    ...
# 72  73            Opava    north Moravia   8746
# 73  74  Ostrava - mesto    north Moravia  10673
# 74  75           Prerov    north Moravia   8819
# 75  76          Sumperk    north Moravia   8369
# 76  77           Vsetin    north Moravia   8909
#
# [77 rows x 4 columns]

# %%
d1=d1[(d1['A11']>9000)]
d1
# Out:
#     A1                   A2               A3    A11
# 0    1          Hl.m. Praha           Prague  12541
# 3    4               Kladno  central Bohemia   9753
# 4    5                Kolin  central Bohemia   9307
# 6    7               Melnik  central Bohemia   9920
# 7    8       Mlada Boleslav  central Bohemia  11277
# 9   10       Praha - vychod  central Bohemia  10124
# 10  11        Praha - zapad  central Bohemia   9622
# 13  14     Ceske Budejovice    south Bohemia  10045
# 14  15        Cesky Krumlov    south Bohemia   9045
# 20  21                Tabor    south Bohemia   9104
# 25  26        Plzen - mesto     west Bohemia  10787
# 29  30              Sokolov     west Bohemia   9650
# 31  32           Ceska Lipa    north Bohemia   9272
# 33  34             Chomutov    north Bohemia   9675
# 35  36              Liberec    north Bohemia   9198
# 36  37           Litomerice    north Bohemia   9065
# 38  39                 Most    north Bohemia  10446
# ...

# %%
merging_acc_dis=df['New_Account'].merge(d1,left_on="district_id",right_on="A1")
merging_acc_dis=merging_acc_dis.drop(columns=['A1'])
merging_acc_dis
# Out:
#       account_id  district_id         frequency               A2  \
# 0           3818           74  MONTHLY ISSUANCE  Ostrava - mesto
# 1           2484           74  MONTHLY ISSUANCE  Ostrava - mesto
# 2           1338           74  MONTHLY ISSUANCE  Ostrava - mesto
# 3          11295           74  MONTHLY ISSUANCE  Ostrava - mesto
# 4           1179           74  MONTHLY ISSUANCE  Ostrava - mesto
# ...          ...          ...               ...              ...
# 2136        3202            8  MONTHLY ISSUANCE   Mlada Boleslav
# 2137        2404            8  MONTHLY ISSUANCE   Mlada Boleslav
# 2138        3461            8  MONTHLY ISSUANCE   Mlada Boleslav
# 2139        3916            8  MONTHLY ISSUANCE   Mlada Boleslav
# 2140         566            8  MONTHLY ISSUANCE   Mlada Boleslav
#
#                    A3    A11
# 0       north Moravia  10673
# 1       north Moravia  10673
# 2       north Moravia  10673
# 3       north Moravia  10673
# 4       north Moravia  10673
# ...

# %%
merging_acc_district_disp=pd.merge(merging_acc_dis,df['New_Disposition'],on='account_id')
merging_acc_district_disp=merging_acc_district_disp.drop(columns=['type','frequency'])
merging_acc_district_disp
# Out:
#       account_id  district_id               A2               A3    A11  \
# 0           3818           74  Ostrava - mesto    north Moravia  10673
# 1           3818           74  Ostrava - mesto    north Moravia  10673
# 2           2484           74  Ostrava - mesto    north Moravia  10673
# 3           1338           74  Ostrava - mesto    north Moravia  10673
# 4           1338           74  Ostrava - mesto    north Moravia  10673
# ...          ...          ...              ...              ...    ...
# 2544        2404            8   Mlada Boleslav  central Bohemia  11277
# 2545        3461            8   Mlada Boleslav  central Bohemia  11277
# 2546        3916            8   Mlada Boleslav  central Bohemia  11277
# 2547         566            8   Mlada Boleslav  central Bohemia  11277
# 2548         566            8   Mlada Boleslav  central Bohemia  11277
#
#       disp_id  client_id
# 0        4601       4601
# 1        4602       4602
# 2        2999       2999
# ...

# %%
merging_all=pd.merge(merging_acc_district_disp,df['New_Card'],on='disp_id')
merging_all
# Out:
#      account_id  district_id               A2               A3    A11  \
# 0          7753           74  Ostrava - mesto    north Moravia  10673
# 1           830           74  Ostrava - mesto    north Moravia  10673
# 2          3391           74  Ostrava - mesto    north Moravia  10673
# 3          4159           74  Ostrava - mesto    north Moravia  10673
# 4          6363           74  Ostrava - mesto    north Moravia  10673
# ..          ...          ...              ...              ...    ...
# 432        1328            8   Mlada Boleslav  central Bohemia  11277
# 433        3359            8   Mlada Boleslav  central Bohemia  11277
# 434        4715            8   Mlada Boleslav  central Bohemia  11277
# 435        1182            8   Mlada Boleslav  central Bohemia  11277
# 436         566            8   Mlada Boleslav  central Bohemia  11277
#
#      disp_id  client_id  card_id     type  issued
# 0       9285       9593     1005  CLASSIC  931107
# ...

# %%
cards_issued_by_district = merging_all.groupby('A2').count()
cards_issued_by_district_clients=cards_issued_by_district.iloc[:,6:7]
cards_issued_by_district_clients
# Out:
#                      card_id
# A2
# Brno - mesto              16
# Ceska Lipa                 6
# Ceske Budejovice           9
# Cesky Krumlov             10
# Chomutov                   9
# Frydek - Mistek           15
# Hl.m. Praha              132
# Hradec Kralove             5
# Karvina                   24
# Kladno                    10
# Kolin                     15
# Liberec                   17
# Litomerice                16
# Melnik                     7
# Mlada Boleslav            10
# Most                       8
# Ostrava - mesto           22
# Pardubice                 17
# Plzen - mesto             10
# Praha - vychod             7
# Praha - zapad              8
# Rychnov nad Kneznou        9
# Sokolov                    8
# Tabor                      9
# Teplice                    9
# Usti nad Labem            12
# Zlin                      17

# %% [markdown]
# ##PROBLEM STATEMENT : 5

# %%
#merging new account and loan
merge_5=pd.merge(df['Loan'],df['New_Account'],on='account_id')
merge_5=merge_5.drop(columns=['frequency','status'])
merge_5
# Out:
#      loan_id  account_id    date  amount  duration  payments  district_id
# 0       5314        1787  930705   96396        12      8033           30
# 1       5316        1801  930711  165960        36      4610           46
# 2       6863        9188  930728  127080        60      2118           45
# 3       5325        1843  930803  105804        36      2939           12
# 4       7240       11013  930906  274740        60      4579            1
# ..       ...         ...     ...     ...       ...       ...          ...
# 677     4989         105  981205  352704        48      7348           21
# 678     5221        1284  981205   52512        12      4376           55
# 679     6402        6922  981206  139488        24      5812            3
# 680     5346        1928  981206   55632        24      2318           70
# 681     6748        8645  981208  240900        60      4015           60
#
# [682 rows x 7 columns]

# %%
merge_dist=pd.merge(merge_5,df['District'],left_on='district_id',right_on='A1')
merge_dist=merge_dist.drop(columns=['A1','A4','A5','A6','A7','A8','A9','A10','A11','A12','A13','A14','A16'])
merge_dist
# Out:
#      loan_id  account_id    date  amount  duration  payments  district_id  \
# 0       5314        1787  930705   96396        12      8033           30
# 1       6903        9337  940604   52128        24      2172           30
# 2       5316        1801  930711  165960        36      4610           46
# 3       6554        7637  970129  390096        48      8127           46
# 4       5973        4784  971124  219456        48      4572           46
# ..       ...         ...     ...     ...       ...       ...          ...
# 677     7050       10065  970923  311232        48      6484           76
# 678     7171       10650  980224  196224        48      4088           76
# 679     7200       10799  980711   31140        60       519           76
# 680     6969        9673  980912   88200        36      2450           76
# 681     6355        6699  970924  127200        48      2650           35
#
#                     A2             A3   A15
# ...

# %%
merge_dist.dtypes
merge_dist['A15']=pd.to_numeric(merge_dist['A15'],errors='coerce').astype(float).astype('Int64')
merge_dist.dtypes
# Out:
# loan_id         int64
# account_id      int64
# date            int64
# amount          int64
# duration        int64
# payments        int64
# district_id     int64
# A2             object
# A3             object
# A15             Int64
# dtype: object

# %%
loan=merge_dist[merge_dist['A15']>6000]
loan
# Out:
#      loan_id  account_id    date  amount  duration  payments  district_id  \
# 23      7240       11013  930906  274740        60      4579            1
# 24      6820        9034  931216   38148        12      3179            1
# 25      4959           2  940105   80952        24      3373            1
# 26      6499        7401  940105   80952        24      3373            1
# 27      5479        2486  940110   24516        12      2043            1
# ..       ...         ...     ...     ...       ...       ...          ...
# 550     6676        8159  950613   29784        24      1241           26
# 551     5350        1967  960421  249312        48      5194           26
# 552     5977        4803  970225   59136        48      1232           26
# 553     6851        9138  970603  272220        60      4537           26
# 554     5531        2753  970930   66432        24      2768           26
#
#                 A2            A3    A15
# ...

# %%
loans_count=loan.groupby('A2').count()
loans_count=loans_count.sort_values(by='account_id')
loans_count
# Out:
#                   loan_id  account_id  date  amount  duration  payments  \
# A2
# Usti nad Labem          3           3     3       3         3         3
# Plzen - mesto           6           6     6       6         6         6
# Teplice                 6           6     6       6         6         6
# Ceske Budejovice        8           8     8       8         8         8
# Pardubice              10          10    10      10        10        10
# Olomouc                14          14    14      14        14        14
# Ostrava - mesto        20          20    20      20        20        20
# Brno - mesto           24          24    24      24        24        24
# Karvina                24          24    24      24        24        24
# Hl.m. Praha            84          84    84      84        84        84
#
#                   district_id  A3  A15
# A2
# Usti nad Labem              3   3    3
# Plzen - mesto               6   6    6
# Teplice                     6   6    6
# ...

# %%
loans_count=loans_count.drop(columns=['account_id','date','amount','duration','payments','district_id','A3','A15'])
loans_count
# Out:
#                   loan_id
# A2
# Usti nad Labem          3
# Plzen - mesto           6
# Teplice                 6
# Ceske Budejovice        8
# Pardubice              10
# Olomouc                14
# Ostrava - mesto        20
# Brno - mesto           24
# Karvina                24
# Hl.m. Praha            84

# %%
loans_count['loan_id'].sum()
# Out:
# 199

# %% [markdown]
# ##Problem statement : 7

# %%
merge_7=df['Order']
merge_7=merge_7[(merge_7['k_symbol']=="SIPO")|
 (merge_7['k_symbol']=="UVER")|
 (merge_7['k_symbol']=="POJISTNE")|
 (merge_7['k_symbol']=="LEASING")]
merge_7
# Out:
#       order_id  account_id bank_to  account_to  amount  k_symbol
# 0        29401           1      YZ    87144583  2452.0      SIPO
# 1        29402           2      ST    89597016  3372.7      UVER
# 2        29403           2      QR    13943797  7266.0      SIPO
# 3        29404           3      WX    83084338  1135.0      SIPO
# 5        29406           3      AB    59972357  3539.0  POJISTNE
# ...        ...         ...     ...         ...     ...       ...
# 6463     46328       11359      EF    37834555  4502.3      UVER
# 6464     46329       11359      OP    33080721  4518.0      SIPO
# 6466     46334       11362      YZ    70641225  4780.0      SIPO
# 6468     46336       11362      ST    40799850   330.0  POJISTNE
# 6470     46338       11362      MN    61540514  5392.0      UVER
#
# [5092 rows x 6 columns]

# %%
merge_7_1=pd.merge(df['New_Account'],merge_7,on='account_id')
merge_7_2=merge_7_1.merge(df['District'],left_on='district_id',right_on='A1')
merge_7_2
# Out:
#       account_id  district_id         frequency  order_id bank_to  account_to  \
# 0            576           55  MONTHLY ISSUANCE     30253      OP    71033382
# 1            704           55  MONTHLY ISSUANCE     30436      IJ    15132719
# 2            192           55  MONTHLY ISSUANCE     29693      IJ    70552640
# 3          10364           55  MONTHLY ISSUANCE     44769      EF    67477196
# 4          10364           55  MONTHLY ISSUANCE     44770      IJ    11477667
# ...          ...          ...               ...       ...     ...         ...
# 5087        3951           22  MONTHLY ISSUANCE     35228      OP     7565194
# 5088         679           22  MONTHLY ISSUANCE     30398      OP    91457056
# 5089         679           22  MONTHLY ISSUANCE     30400      UV    84744864
# 5090        2182           22  MONTHLY ISSUANCE     32609      OP    88771032
# 5091        2152           22  MONTHLY ISSUANCE     32556      QR    56643396
#
# ...

# %%
merge_sipo=merge_7_1[(merge_7_1['k_symbol']=="SIPO")]
merge_pojistne=merge_7_1[(merge_7_1['k_symbol']=='POJISTNE')]
merge_uver=merge_7_1[(merge_7_1['k_symbol']=='UVER')]
merge_leasing=merge_7_1[(merge_7_1['k_symbol']=="LEASING")]

# %%
merge_sipo
# Out:
#       account_id  district_id         frequency  order_id bank_to  account_to  \
# 0            576           55  MONTHLY ISSUANCE     30253      OP    71033382
# 1           3818           74  MONTHLY ISSUANCE     35031      QR    35474443
# 3            704           55  MONTHLY ISSUANCE     30436      IJ    15132719
# 4           2378           16  MONTHLY ISSUANCE     32909      EF     1222903
# 5           2632           24  MONTHLY ISSUANCE     33279      EF    40250009
# ...          ...          ...               ...       ...     ...         ...
# 5084         906           59  MONTHLY ISSUANCE     30732      AB    85822999
# 5085         845           14  MONTHLY ISSUANCE     30629      IJ    33191889
# 5086         124           55  MONTHLY ISSUANCE     29605      IJ    11366123
# 5089        1573           63  MONTHLY ISSUANCE     31720      IJ    19240260
# 5090        3276            1  MONTHLY ISSUANCE     34260      IJ    54098749
#
#       amount k_symbol
# ...

# %%
merge_pojistne
# Out:
#       account_id  district_id         frequency  order_id bank_to  account_to  \
# 2           3818           74  MONTHLY ISSUANCE     35033      CD    34760767
# 6           2632           24  MONTHLY ISSUANCE     33281      IJ    36942219
# 9            793           47  MONTHLY ISSUANCE     30562      YZ    95059883
# 11          2484           74  MONTHLY ISSUANCE     33069      GH    75644820
# 14          1726           48  MONTHLY ISSUANCE     31928      EF    89946835
# ...          ...          ...               ...       ...     ...         ...
# 5049        3033           69  MONTHLY ISSUANCE     33891      UV    11267763
# 5063        2440           19  MONTHLY ISSUANCE     32999      GH    32329070
# 5075        1318           56  MONTHLY ISSUANCE     31331      MN    13490295
# 5087         124           55  MONTHLY ISSUANCE     29607      OP    34663748
# 5091        3276            1  MONTHLY ISSUANCE     34262      WX    88365083
#
#       amount  k_symbol
# ...

# %%
merge_uver
# Out:
#       account_id  district_id         frequency  order_id bank_to  account_to  \
# 55          5270           44  MONTHLY ISSUANCE     37180      CD    13973260
# 64         11265           15  MONTHLY ISSUANCE     46186      KL    33709621
# 67         10364           55  MONTHLY ISSUANCE     44770      IJ    11477667
# 74          3834           54  MONTHLY ISSUANCE     35053      WX    34075695
# 89          9307           68  MONTHLY ISSUANCE     43182      EF    53406888
# ...          ...          ...               ...       ...     ...         ...
# 5056         938           70  MONTHLY ISSUANCE     30779      GH    56959378
# 5058        3501           36  MONTHLY ISSUANCE     34587      EF    31481027
# 5068        1177           27  MONTHLY ISSUANCE     31122      OP    30046618
# 5073        1318           56  MONTHLY ISSUANCE     31328      ST    77757256
# 5088         777           30  MONTHLY ISSUANCE     30535      GH     7662755
#
#       amount k_symbol
# ...

# %%
merge_leasing
# Out:
#       account_id  district_id                   frequency  order_id bank_to  \
# 18           485            6  ISSUANCE AFTER TRANSACTION     30139      AB
# 25          2393           10            MONTHLY ISSUANCE     32931      AB
# 34          2087            7             WEEKLY ISSUANCE     32465      IJ
# 54          3760           44            MONTHLY ISSUANCE     34947      YZ
# 77           456           49            MONTHLY ISSUANCE     30089      WX
# ...          ...          ...                         ...       ...     ...
# 4993        3156            1  ISSUANCE AFTER TRANSACTION     34080      KL
# 5020        4386           51             WEEKLY ISSUANCE     35829      ST
# 5039        2775           30            MONTHLY ISSUANCE     33512      EF
# 5078        4332           74            MONTHLY ISSUANCE     35767      WX
# 5082        3048           74             WEEKLY ISSUANCE     33913      UV
#
#       account_to  amount k_symbol
# ...

# %%
merge_sipo.groupby('district_id')['amount'].sum()
dt=pd.DataFrame(merge_sipo.groupby('district_id')['amount'].sum())
dt.rename(columns={'amount': 'amount_SIPO'}, inplace=True)
dt
# Out:
#              amount_SIPO
# district_id
# 1              1738720.0
# 2               124334.0
# 3               147921.0
# 4               161270.0
# 5               249678.0
# ...                  ...
# 73              167385.0
# 74              388338.0
# 75              199332.0
# 76              180162.0
# 77              135043.0
#
# [77 rows x 1 columns]

# %%
merge_leasing.groupby('district_id')['amount'].sum()
dtlease=pd.DataFrame(merge_leasing.groupby('district_id')['amount'].sum())
dtlease.rename(columns={'amount': 'amount_LEASING'}, inplace=True)
dtlease
# Out:
#              amount_LEASING
# district_id
# 1                  116879.9
# 2                   13077.0
# 3                    4753.3
# 4                   11193.2
# 5                   15603.0
# ...                     ...
# 73                  12318.0
# 74                  25164.9
# 75                   7335.2
# 76                  14743.6
# 77                   7196.0
#
# [73 rows x 1 columns]

# %%
merge_uver.groupby('district_id')['amount'].sum()
dtuver=pd.DataFrame(merge_uver.groupby('district_id')['amount'].sum())
dtuver.rename(columns={'amount': 'amount_UVER'}, inplace=True)
dtuver
# Out:
#              amount_UVER
# district_id
# 1               379522.4
# 2                23021.3
# 3                31910.4
# 4                26955.2
# 5                45805.3
# ...                  ...
# 73               35865.0
# 74              111525.9
# 75               21215.2
# 76               17767.2
# 77               21382.5
#
# [77 rows x 1 columns]

# %%
merge_pojistne.groupby('district_id')['amount'].sum()
dtpoji=pd.DataFrame(merge_pojistne.groupby('district_id')['amount'].sum())

dtpoji.rename(columns={'amount': 'amount_POJISTNE'}, inplace=True)
dtpoji.sort_values(by='amount_POJISTNE',ascending=False)
# Out:
#              amount_POJISTNE
# district_id
# 1                   117872.0
# 70                   27969.0
# 54                   27271.0
# 9                    26259.0
# 74                   25380.0
# ...                      ...
# 26                    1320.0
# 40                    1176.0
# 29                    1140.0
# 49                     713.0
# 18                     567.0
#
# [77 rows x 1 columns]

# %% [markdown]
# ##Problem statement : 8

# %%
merge_8=pd.merge(df['New_Account'],df['Loan'],on='account_id')
merge_8
merge_9=merge_8.merge(df['District'],left_on='district_id',right_on='A1')
merge_9
# Out:
#      account_id  district_id         frequency  loan_id    date  amount  \
# 0          5270           44  MONTHLY ISSUANCE     6077  931122   79608
# 1          5385           44   WEEKLY ISSUANCE     6103  940407  149340
# 2          8027           44   WEEKLY ISSUANCE     6642  940605   77640
# 3          3037           44  MONTHLY ISSUANCE     5593  960418  277884
# 4         10942           44   WEEKLY ISSUANCE     7227  951002  314520
# ..          ...          ...               ...      ...     ...     ...
# 677        6950           36  MONTHLY ISSUANCE     6415  970212  475680
# 678        4052           36   WEEKLY ISSUANCE     5799  971228  106128
# 679        8026           36  MONTHLY ISSUANCE     6641  970909  128268
# 680        1776           36  MONTHLY ISSUANCE     5313  980527   43200
# 681        6699           35  MONTHLY ISSUANCE     6355  970924  127200
#
#      duration  payments status  A1  ... A7 A8  A9   A10   A11   A12   A13  \
# ...

# %%
merge_9=merge_9.drop(columns=['A1','A4','A5','A6','A7','A8','A9','A10','A11','A12','A13','A14','A15','A16','frequency','duration','amount','payments'])
merge_9
# Out:
#      account_id  district_id  loan_id    date status                 A2  \
# 0          5270           44     6077  931122      A            Chrudim
# 1          5385           44     6103  940407      C            Chrudim
# 2          8027           44     6642  940605      A            Chrudim
# 3          3037           44     5593  960418      D            Chrudim
# 4         10942           44     7227  951002      C            Chrudim
# ..          ...          ...      ...     ...    ...                ...
# 677        6950           36     6415  970212      C            Liberec
# 678        4052           36     5799  971228      C            Liberec
# 679        8026           36     6641  970909      C            Liberec
# 680        1776           36     5313  980527      C            Liberec
# 681        6699           35     6355  970924      C  Jablonec n. Nisou
#
#                 A3
# 0     east Bohemia
# 1     east Bohemia
# 2     east Bohemia
# 3     east Bohemia
# ...

# %%
merge_9_a=merge_9[(merge_9['status']=='A')]
finalA=merge_9_a.groupby('A2').count()
data1=finalA['status']
data1=data1.reset_index()
data1.rename(columns={"status": "StatusA"}, inplace=True)
data1
# Out:
#                   A2  StatusA
# 0            Benesov        1
# 1             Beroun        1
# 2            Blansko        3
# 3            Breclav        1
# 4       Brno - mesto        4
# ..               ...      ...
# 64            Vsetin        1
# 65            Vyskov        3
# 66  Zdar nad Sazavou        4
# 67              Zlin        6
# 68            Znojmo        1
#
# [69 rows x 2 columns]

# %%
merge_9_b=merge_9[(merge_9['status']=='B')]
finalB=merge_9_b.groupby('A2').count()
data2=finalB['status']
data2=data2.reset_index()
data2.rename(columns={"status": "StatusB"}, inplace=True)
data2
# Out:
#                    A2  StatusB
# 0             Breclav        1
# 1        Brno - mesto        2
# 2             Bruntal        1
# 3       Cesky Krumlov        1
# 4            Chomutov        1
# 5     Frydek - Mistek        1
# 6         Hl.m. Praha        3
# 7   Jindrichuv Hradec        1
# 8        Karlovy Vary        2
# 9          Kutna Hora        2
# 10            Olomouc        1
# 11              Opava        1
# 12    Ostrava - mesto        2
# 13      Praha - zapad        1
# 14            Pribram        1
# 15          Prostejov        1
# 16           Rakovnik        1
# 17            Sokolov        1
# 18         Strakonice        1
# 19              Tabor        2
# 20             Tachov        2
# 21             Trebic        1
# 22             Znojmo        1

# %%
merge_9_c=merge_9[(merge_9['status']=='C')]
finalC=merge_9_c.groupby('A2').count()
data3=finalC['status']
data3=data3.reset_index()
data3.rename(columns={"status": "StatusC"}, inplace=True)
data3
# Out:
#                   A2  StatusC
# 0            Benesov        5
# 1             Beroun        3
# 2            Blansko        3
# 3            Breclav        5
# 4       Brno - mesto       15
# ..               ...      ...
# 71            Vsetin        5
# 72            Vyskov        4
# 73  Zdar nad Sazavou        3
# 74              Zlin       10
# 75            Znojmo        4
#
# [76 rows x 2 columns]

# %%
merge_9_d=merge_9[(merge_9['status']=='D')]
finalD=merge_9_d.groupby('A2').count()
data4=finalD['status']
data4=data4.reset_index()
data4.rename(columns={"status": "StatusD"}, inplace=True)
data4
# Out:
#                      A2  StatusD
# 0                Beroun        2
# 1               Blansko        1
# 2          Brno - mesto        3
# 3         Brno - venkov        1
# 4               Bruntal        2
# 5      Ceske Budejovice        1
# 6               Chrudim        2
# 7             Domazlice        1
# 8        Havlickuv Brod        1
# 9           Hl.m. Praha        4
# 10       Hradec Kralove        1
# 11              Jesenik        2
# 12              Karvina        3
# 13               Kladno        1
# 14              Klatovy        1
# 15             Kromeriz        1
# 16           Kutna Hora        1
# 17       Mlada Boleslav        1
# 18           Novy Jicin        1
# 19              Olomouc        1
# 20                Opava        2
# 21      Ostrava - mesto        1
# 22        Plzen - mesto        1
# 23           Prachatice        1
# 24             Rokycany        1
# 25  Rychnov nad Kneznou        1
# 26           Strakonice        2
# ...

# %% [markdown]
# ##Problem Statement : 10

# %%
merge_10=pd.merge(df['New_Account'],df['New_Disposition'],on='account_id')
merge_10
merge_10=merge_10.drop(columns=['frequency','disp_id'])
merge_10
# Out:
#       account_id  district_id  client_id   type
# 0            576           55        692  OWNER
# 1            576           55        693   USER
# 2           3818           74       4601  OWNER
# 3           3818           74       4602   USER
# 4            704           55        844  OWNER
# ...          ...          ...        ...    ...
# 5364        3958           59       4775   USER
# 5365         777           30        929  OWNER
# 5366        1573           63       1906  OWNER
# 5367        3276            1       3965  OWNER
# 5368        3276            1       3966   USER
#
# [5369 rows x 4 columns]

# %%
merge_10_1=merge_10.merge(df['District'],left_on='district_id',right_on='A1')
merge_10_1
# Out:
#       account_id  district_id  client_id   type  A1             A2  \
# 0            576           55        692  OWNER  55  Brno - venkov
# 1            576           55        693   USER  55  Brno - venkov
# 2            704           55        844  OWNER  55  Brno - venkov
# 3            704           55        845   USER  55  Brno - venkov
# 4            192           55        232  OWNER  55  Brno - venkov
# ...          ...          ...        ...    ...  ..            ...
# 5364        3951           22       4766  OWNER  22      Domazlice
# 5365         679           22        815  OWNER  22      Domazlice
# 5366        2182           22       2642  OWNER  22      Domazlice
# 5367        2152           22       2604  OWNER  22      Domazlice
# 5368        2152           22       2605   USER  22      Domazlice
#
#                  A3      A4  A5  A6  A7  A8  A9   A10   A11   A12   A13  A14  \
# 0     south Moravia  157042  49  70  18   0   9  33.9  8743  1.88  2.43  111
# ...

# %%
merge_10_1=merge_10_1.drop(columns=['A4','A5','A6','A7','A8','A9','A10','A11','A12','A13','A14','A15','A16','A1'])
merge_10_1
# Out:
#       account_id  district_id  client_id   type             A2             A3
# 0            576           55        692  OWNER  Brno - venkov  south Moravia
# 1            576           55        693   USER  Brno - venkov  south Moravia
# 2            704           55        844  OWNER  Brno - venkov  south Moravia
# 3            704           55        845   USER  Brno - venkov  south Moravia
# 4            192           55        232  OWNER  Brno - venkov  south Moravia
# ...          ...          ...        ...    ...            ...            ...
# 5364        3951           22       4766  OWNER      Domazlice   west Bohemia
# 5365         679           22        815  OWNER      Domazlice   west Bohemia
# 5366        2182           22       2642  OWNER      Domazlice   west Bohemia
# 5367        2152           22       2604  OWNER      Domazlice   west Bohemia
# 5368        2152           22       2605   USER      Domazlice   west Bohemia
#
# [5369 rows x 6 columns]

# %%
merge_10_1=merge_10_1[(merge_10_1['type']=='OWNER')]
merge_10_1
# Out:
#       account_id  district_id  client_id   type             A2             A3
# 0            576           55        692  OWNER  Brno - venkov  south Moravia
# 2            704           55        844  OWNER  Brno - venkov  south Moravia
# 4            192           55        232  OWNER  Brno - venkov  south Moravia
# 5          10364           55      12754  OWNER  Brno - venkov  south Moravia
# 7            497           55        597  OWNER  Brno - venkov  south Moravia
# ...          ...          ...        ...    ...            ...            ...
# 5363       10134           22      12468  OWNER      Domazlice   west Bohemia
# 5364        3951           22       4766  OWNER      Domazlice   west Bohemia
# 5365         679           22        815  OWNER      Domazlice   west Bohemia
# 5366        2182           22       2642  OWNER      Domazlice   west Bohemia
# 5367        2152           22       2604  OWNER      Domazlice   west Bohemia
#
# [4500 rows x 6 columns]

# %%
merge_10_1=merge_10_1.groupby('A2').count()
merge_10_1.rename(columns={"account_id": "accounts"}, inplace=True)
merge_10_1=merge_10_1.drop(columns=['A3','type','district_id','client_id'])
merge_10_1
# Out:
#                   accounts
# A2
# Benesov                 42
# Beroun                  50
# Blansko                 50
# Breclav                 44
# Brno - mesto           128
# ...                    ...
# Vsetin                  40
# Vyskov                  49
# Zdar nad Sazavou        53
# Zlin                    92
# Znojmo                  39
#
# [77 rows x 1 columns]

# %% [markdown]
# ##problem statement: 11

# %%
merge_11=pd.merge(df['New_Card'],df['New_Disposition'],on='disp_id')
merge_11_1=pd.merge(merge_11,df['New_Account'],on='account_id')
merge_11_2=pd.merge(merge_11_1,df['District'],left_on='district_id',right_on='A1')
merge_11_2
# Out:
#      card_id  disp_id   type_x  issued  client_id  account_id type_y  \
# 0       1005     9285  CLASSIC  931107       9593        7753  OWNER
# 1        166      999  CLASSIC  950305        999         830  OWNER
# 2        890     7422  CLASSIC  960908       7422        6148  OWNER
# 3        513     3260  CLASSIC  970315       3260        2702  OWNER
# 4        350     2226  CLASSIC  970420       2226        1835  OWNER
# ..       ...      ...      ...     ...        ...         ...    ...
# 887      726     4721  CLASSIC  980226       4721        3915  OWNER
# 888      156      906   JUNIOR  980407        906         756  OWNER
# 889      338     2146  CLASSIC  980416       2146        1770  OWNER
# 890      755     5002  CLASSIC  980416       5002        4150  OWNER
# 891      306     1929  CLASSIC  981211       1929        1591  OWNER
#
#      district_id         frequency  A1  ... A7 A8  A9    A10    A11   A12  \
# ...

# %%
merge_11_2=merge_11_2.drop(columns=['type_y','issued','frequency','A1','A4','A5','A6','A7','A8','A9','A10','A11','A12','A13','A14'])
merge_11_2
# Out:
#      card_id  disp_id   type_x  client_id  account_id  district_id  \
# 0       1005     9285  CLASSIC       9593        7753           74
# 1        166      999  CLASSIC        999         830           74
# 2        890     7422  CLASSIC       7422        6148           74
# 3        513     3260  CLASSIC       3260        2702           74
# 4        350     2226  CLASSIC       2226        1835           74
# ..       ...      ...      ...        ...         ...          ...
# 887      726     4721  CLASSIC       4721        3915           65
# 888      156      906   JUNIOR        906         756           65
# 889      338     2146  CLASSIC       2146        1770           65
# 890      755     5002  CLASSIC       5002        4150           65
# 891      306     1929  CLASSIC       1929        1591           65
#
#                   A2             A3    A15    A16
# 0    Ostrava - mesto  north Moravia  18782  18347
# 1    Ostrava - mesto  north Moravia  18782  18347
# ...

# %%
merge_11_3=pd.merge(merge_11_2,df['New_Client'],on='client_id')
merge_11_3=merge_11_3.drop(columns=['district_id_y','Unnamed: 0','A15'])
merge_11_3
# Out:
#      card_id  disp_id   type_x  client_id  account_id  district_id_x  \
# 0       1005     9285  CLASSIC       9593        7753             74
# 1        166      999  CLASSIC        999         830             74
# 2        890     7422  CLASSIC       7422        6148             74
# 3        513     3260  CLASSIC       3260        2702             74
# 4        350     2226  CLASSIC       2226        1835             74
# ..       ...      ...      ...        ...         ...            ...
# 887      726     4721  CLASSIC       4721        3915             65
# 888      156      906   JUNIOR        906         756             65
# 889      338     2146  CLASSIC       2146        1770             65
# 890      755     5002  CLASSIC       5002        4150             65
# 891      306     1929  CLASSIC       1929        1591             65
#
#                   A2             A3    A16  birth_number  gender  age  \
# ...

# %%
merge_11_3_men=merge_11_3[(merge_11_3['gender']=='MALE')&(merge_11_3['type_x']=='GOLD')]
merge_11_3_men_Bohemia=merge_11_3_men[(merge_11_3_men['A3']=='north Bohemia')|
 (merge_11_3_men['A3']=='east Bohemia')|(merge_11_3_men['A3']=='west Bohemia')|(merge_11_3_men['A3']=='central Bohemia')]
merge_11_3_men_Bohemia
# Out:
#      card_id  disp_id type_x  client_id  account_id  district_id_x  \
# 111      125      694   GOLD        694         577             29
# 113       99      548   GOLD        548         456             49
# 264      282     1799   GOLD       1799        1485             36
# 310      261     1629   GOLD       1629        1345             28
# 328      354     2265   GOLD       2265        1867             52
# 367      561     3581   GOLD       3581        2966             33
# 383      531     3378   GOLD       3378        2796              5
# 483      546     3465   GOLD       3465        2867             30
# 498        3       41   GOLD         41          33             22
# 501      724     4701   GOLD       4701        3899             22
# 521      599     3824   GOLD       3824        3163             41
# 594     1176    12502   GOLD      12810       10411             39
# 598      461     2977   GOLD       2977        2466             39
# ...

# %%
merge_11_3_men_Moravia=merge_11_3_men[(merge_11_3_men['A3']=='north Moravia')|
 (merge_11_3_men['A3']=='south Moravia')]
# cardd_ndisp_acct_distt_ncli_men_Moravia.to_excel('car_m_M.xlsx',index=False)
merge_11_3_men_Moravia
# Out:
#      card_id  disp_id type_x  client_id  account_id  district_id_x  \
# 7        638     4100   GOLD       4100        3391             74
# 13       906     7683   GOLD       7683        6363             74
# 15       475     3075   GOLD       3075        2547             74
# 57       362     2320   GOLD       2320        1910             60
# 61         1        9   GOLD          9           7             60
# 64       208     1246   GOLD       1246        1039             70
# 80       761     5128   GOLD       5128        4255             70
# 93       296     1876   GOLD       1876        1547             72
# 294     1007     9333   GOLD       9641        7795             64
# 303      269     1718   GOLD       1718        1417             75
# 389      617     3944   GOLD       3944        3260             68
# 439      874     7127   GOLD       7127        5891             54
# 440      382     2445   GOLD       2445        2013             54
# ...

# %%
print('Yes,we say customers from Bohemia are the ones having more male customers possessing Gold cards in comparison of Moravia'if len(merge_11_3_men_Bohemia)>len(merge_11_3_men_Moravia)
else "No,we cann't say that customers from Bohemia are the ones having more male customers possessing Gold cards in comparison of Moravia" )
# Out:
# No,we cann't say that customers from Bohemia are the ones having more male customers possessing Gold cards in comparison of Moravia

# %% [markdown]
# ##Problem statement : 12

# %%
merge_12=pd.merge(df['New_Disposition'],df['New_Transaction'],on='account_id')
merge_12=merge_12.drop(columns=['date','amount','client_id'])
credit_transactions = merge_12[merge_12['type_y'] == 'CREDIT']
credit_transactions_loan=pd.merge(credit_transactions,df['New_Card'],on='disp_id')
credit_transactions_loan=credit_transactions_loan.drop(columns=['type','issued'])
credit_transactions_loan
# Out:
#        disp_id  account_id type_x  type_y  card_id
# 0            9           7  OWNER  CREDIT        1
# 1            9           7  OWNER  CREDIT        1
# 2            9           7  OWNER  CREDIT        1
# 3            9           7  OWNER  CREDIT        1
# 4            9           7  OWNER  CREDIT        1
# ...        ...         ...    ...     ...      ...
# 81982    13660       11359  OWNER  CREDIT     1247
# 81983    13660       11359  OWNER  CREDIT     1247
# 81984    13660       11359  OWNER  CREDIT     1247
# 81985    13660       11359  OWNER  CREDIT     1247
# 81986    13660       11359  OWNER  CREDIT     1247
#
# [81987 rows x 5 columns]

# %%
credit_transactions = merge_12[merge_12['type_y'] == 'CREDIT']
owner_credit_transactions = credit_transactions[credit_transactions['type_x'] == 'OWNER']
unique_owner_credit_transactions = owner_credit_transactions.drop_duplicates(subset=['account_id'])
num_unique_customers_with_credit_and_loan = unique_owner_credit_transactions['disp_id'].nunique()
unique_owner_credit_transactions
# Out:
#          disp_id  account_id type_x  type_y
# 0              1           1  OWNER  CREDIT
# 238            2           2  OWNER  CREDIT
# 1192           4           3  OWNER  CREDIT
# 1422           6           4  OWNER  CREDIT
# 1607           7           5  OWNER  CREDIT
# ...          ...         ...    ...     ...
# 1251464    13623       11333  OWNER  CREDIT
# 1251829    13647       11349  OWNER  CREDIT
# 1252433    13660       11359  OWNER  CREDIT
# 1252809    13663       11362  OWNER  CREDIT
# 1253152    13690       11382  OWNER  CREDIT
#
# [4500 rows x 4 columns]

# %%
print("Number of unique customers with credit cards, available for a loan, and no repetitions of account_id:", num_unique_customers_with_credit_and_loan)
# Out:
# Number of unique customers with credit cards, available for a loan, and no repetitions of account_id: 4500

# %% [markdown]
# ##Problem statement : 13

# %%
class_jr=pd.read_excel("/content/drive/MyDrive/Edulyt India - Data for Project - 3 (2).xlsx",sheet_name='New_Card')
disp=pd.read_excel("/content/drive/MyDrive/Edulyt India - Data for Project - 3 (2).xlsx",sheet_name='New_Disposition')
del disp['type']
class_jr=pd.merge(class_jr,disp,on='disp_id')
class_jr
# Out:
#      card_id  disp_id     type  issued  client_id  account_id
# 0       1005     9285  CLASSIC  931107       9593        7753
# 1        104      588  CLASSIC  940119        588         489
# 2        747     4915  CLASSIC  940205       4915        4078
# 3         70      439  CLASSIC  940208        439         361
# 4        577     3687  CLASSIC  940215       3687        3050
# ..       ...      ...      ...     ...        ...         ...
# 887      125      694     GOLD  981226        694         577
# 888      674     4360  CLASSIC  981228       4360        3614
# 889      322     2063  CLASSIC  981228       2063        1698
# 890      685     4467  CLASSIC  981229       4467        3705
# 891      635     4083  CLASSIC  981229       4083        3377
#
# [892 rows x 6 columns]

# %%
trans=df['New_Transaction']
trans
# Out:
#          account_id    date    type   amount
# 0              2378  930101  CREDIT    700.0
# 1               576  930101  CREDIT    900.0
# 2               704  930101  CREDIT   1000.0
# 3              3818  930101  CREDIT    600.0
# 4              1972  930102  CREDIT    400.0
# ...             ...     ...     ...      ...
# 1048570        3779  981219   DEBIT  12200.0
# 1048571        3787  981219   DEBIT   2600.0
# 1048572        3789  981219   DEBIT   4900.0
# 1048573        3791  981219   DEBIT  23500.0
# 1048574        3789  981219   DEBIT  11100.0
#
# [1048575 rows x 4 columns]

# %%
trans=trans[(trans['type']=='DEBIT')]
trans
# Out:
#          account_id    date   type   amount
# 136            2378  930131  DEBIT  34700.0
# 189             485  930203  DEBIT  25300.0
# 222            3510  930206  DEBIT   1600.0
# 233            2378  930207  DEBIT   9612.0
# 249            2122  930207  DEBIT  14100.0
# ...             ...     ...    ...      ...
# 1048570        3779  981219  DEBIT  12200.0
# 1048571        3787  981219  DEBIT   2600.0
# 1048572        3789  981219  DEBIT   4900.0
# 1048573        3791  981219  DEBIT  23500.0
# 1048574        3789  981219  DEBIT  11100.0
#
# [648366 rows x 4 columns]

# %%
cust_class_jr=pd.merge(class_jr,trans,on='account_id')
cust_class_jr
# Out:
#         card_id  disp_id   type_x  issued  client_id  account_id    date  \
# 0          1005     9285  CLASSIC  931107       9593        7753  930310
# 1          1005     9285  CLASSIC  931107       9593        7753  930409
# 2          1005     9285  CLASSIC  931107       9593        7753  930420
# 3          1005     9285  CLASSIC  931107       9593        7753  930430
# 4          1005     9285  CLASSIC  931107       9593        7753  930504
# ...         ...      ...      ...     ...        ...         ...     ...
# 138263      635     4083  CLASSIC  981229       4083        3377  981122
# 138264      635     4083  CLASSIC  981229       4083        3377  981126
# 138265      635     4083  CLASSIC  981229       4083        3377  981130
# 138266      635     4083  CLASSIC  981229       4083        3377  981205
# 138267      635     4083  CLASSIC  981229       4083        3377  981209
#
#        type_y   amount
# 0       DEBIT  12000.0
# 1       DEBIT  27500.0
# ...

# %%
cust_class_jr_debit=cust_class_jr[(cust_class_jr['type_x']=='CLASSIC')|(cust_class_jr['type_x']=='JUNIOR')]
# cust_class_jr_debit.to_excel('class_jr.xlsx',index=False)
cust_class_jr_debit
# Out:
#         card_id  disp_id   type_x  issued  client_id  account_id    date  \
# 0          1005     9285  CLASSIC  931107       9593        7753  930310
# 1          1005     9285  CLASSIC  931107       9593        7753  930409
# 2          1005     9285  CLASSIC  931107       9593        7753  930420
# 3          1005     9285  CLASSIC  931107       9593        7753  930430
# 4          1005     9285  CLASSIC  931107       9593        7753  930504
# ...         ...      ...      ...     ...        ...         ...     ...
# 138263      635     4083  CLASSIC  981229       4083        3377  981122
# 138264      635     4083  CLASSIC  981229       4083        3377  981126
# 138265      635     4083  CLASSIC  981229       4083        3377  981130
# 138266      635     4083  CLASSIC  981229       4083        3377  981205
# 138267      635     4083  CLASSIC  981229       4083        3377  981209
#
#        type_y   amount
# 0       DEBIT  12000.0
# 1       DEBIT  27500.0
# ...

# %%
cust_gold_card=cust_class_jr[(cust_class_jr['type_x']=='GOLD')]
# cust_gold_card.to_excel('gold_card.xlsx',index=False)
cust_gold_card
# Out:
#         card_id  disp_id type_x  issued  client_id  account_id    date type_y  \
# 6951        208     1246   GOLD  950208       1246        1039  930609  DEBIT
# 6952        208     1246   GOLD  950208       1246        1039  930709  DEBIT
# 6953        208     1246   GOLD  950208       1246        1039  930907  DEBIT
# 6954        208     1246   GOLD  950208       1246        1039  931007  DEBIT
# 6955        208     1246   GOLD  950208       1246        1039  931106  DEBIT
# ...         ...      ...    ...     ...        ...         ...     ...    ...
# 137855      125      694   GOLD  981226        694         577  981031  DEBIT
# 137856      125      694   GOLD  981226        694         577  981108  DEBIT
# 137857      125      694   GOLD  981226        694         577  981120  DEBIT
# 137858      125      694   GOLD  981226        694         577  981130  DEBIT
# 137859      125      694   GOLD  981226        694         577  981208  DEBIT
#
#          amount
# ...

# %%
print( "Gold are having greater in debit" if len(cust_gold_card)>len(cust_class_jr_debit) else "classic and junior having more in debit")
# Out:
# classic and junior having more in debit

# %% [markdown]
# ##problem statement : 14

# %%
merge_14=pd.merge(df['New_Disposition'],df['New_Client'],on='client_id')
merge_14=merge_14.drop(columns=['disp_id','Unnamed: 0'])
merge_14
# Out:
#       client_id  account_id   type  birth_number  district_id  gender  age  \
# 0             1           1  OWNER        701213           18  FEMALE   29
# 1             2           2  OWNER        450204            1    MALE   54
# 2             3           2   USER        401009            1  FEMALE   59
# 3             4           3  OWNER        561201            5    MALE   43
# 4             5           3   USER        600703            5  FEMALE   39
# ...         ...         ...    ...           ...          ...     ...  ...
# 5364      13955       11349  OWNER        451030            1  FEMALE   54
# 5365      13956       11349   USER        430406            1    MALE   56
# 5366      13968       11359  OWNER        680413           61    MALE   31
# 5367      13971       11362  OWNER        621019           67  FEMALE   37
# 5368      13998       11382  OWNER        530812           74  FEMALE   46
#
#        age_levels
# 0           ADULT
# 1     MIDDLE AGED
# ...

# %%
merge_14_1=pd.merge(merge_14,df['Loan'],on='account_id')
merge_14_1
# Out:
#      client_id  account_id   type  birth_number  district_id  gender  age  \
# 0            2           2  OWNER        450204            1    MALE   54
# 1            3           2   USER        401009            1  FEMALE   59
# 2           25          19  OWNER        390423           21  FEMALE   60
# 3           31          25  OWNER        620209           68    MALE   37
# 4           45          37  OWNER        520826           20    MALE   47
# ..         ...         ...    ...           ...          ...     ...  ...
# 822      13924       11328  OWNER        520909           54  FEMALE   47
# 823      13955       11349  OWNER        451030            1  FEMALE   54
# 824      13956       11349   USER        430406            1    MALE   56
# 825      13968       11359  OWNER        680413           61    MALE   31
# 826      13971       11362  OWNER        621019           67  FEMALE   37
#
#       age_levels  loan_id    date  amount  duration  payments status
# ...

# %%
merge=merge_14_1[(merge_14_1['age_levels']=='MIDDLE AGED')| (merge_14_1['age_levels']=='ADULT')]
merge
# Out:
#      client_id  account_id   type  birth_number  district_id  gender  age  \
# 0            2           2  OWNER        450204            1    MALE   54
# 1            3           2   USER        401009            1  FEMALE   59
# 2           25          19  OWNER        390423           21  FEMALE   60
# 3           31          25  OWNER        620209           68    MALE   37
# 4           45          37  OWNER        520826           20    MALE   47
# ..         ...         ...    ...           ...          ...     ...  ...
# 822      13924       11328  OWNER        520909           54  FEMALE   47
# 823      13955       11349  OWNER        451030            1  FEMALE   54
# 824      13956       11349   USER        430406            1    MALE   56
# 825      13968       11359  OWNER        680413           61    MALE   31
# 826      13971       11362  OWNER        621019           67  FEMALE   37
#
#       age_levels  loan_id    date  amount  duration  payments status
# ...

# %%
merge_repay=merge[(merge['age_levels']=='MIDDLE AGED')&(merge['status']=='A')]
len(merge_repay)
# Out:
# 162

# %%
merge1_repay=merge[(merge['age_levels']=='ADULT')&(merge['status']=='A')]
len(merge1_repay)
# Out:
# 59

# %%
print("Middle age PAY LOAN REPAYMENTS GOOD AS COMPARED TO adults" if len(merge_repay)>len(merge1_repay) else "MIIDDLE AGED PAY LOAN REPAYMENTS GOOD AS COMPARED TO ADULT")
# Out:
# Middle age PAY LOAN REPAYMENTS GOOD AS COMPARED TO adults
